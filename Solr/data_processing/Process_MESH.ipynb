# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # MESH

# %%
important_columns_mesh = [
    'Class ID',
    'Preferred Label',
    'Synonyms',
    'Obsolete',
    'Semantic Types',
    'CUI'
]

# %%
mesh_df = pd.read_csv(
    "data/MESH.csv",      # relative python path to subdirectory
    sep=',',
    usecols=important_columns_mesh,
    dtype=str
)
mesh_df
# Out:
#                                                 Class ID  \
# 0      http://purl.bioontology.org/ontology/MESH/C000...
# 1      http://purl.bioontology.org/ontology/MESH/C585345
# 2      http://purl.bioontology.org/ontology/MESH/C000...
# 3      http://purl.bioontology.org/ontology/MESH/C000...
# 4      http://purl.bioontology.org/ontology/MESH/C049340
# ...                                                  ...
# 87269  http://purl.bioontology.org/ontology/MESH/C088692
# 87270  http://purl.bioontology.org/ontology/MESH/C481277
# 87271  http://purl.bioontology.org/ontology/MESH/C111764
# 87272  http://purl.bioontology.org/ontology/MESH/C000...
# 87273                           http://purl.bioontology.
#
#                                          Preferred Label  \
# 0           technetium 99m hydroxyethylene-diphosphonate
# 1                              Tardbp protein, zebrafish
# 2      Autographa californica multiple nuclear polyhe...
# 3                            Leeuwenhoekiella blandensis
# 4                                    N-demethylmenogaril
# ...                                                  ...
# 87269  2-(4-(biscarboxymethyl)amino-3-(carboxymethoxy...
# 87270                         Yrr1 protein, S cerevisiae
# 87271                                  3-epi-actinobolin
# 87272                    2-tridecanyl-1,4-naphthoquinone
# 87273                                                NaN
#
#                                                 Synonyms Obsolete  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate    false
# 1      Tardbpl-FL protein, zebrafish|Tardbpl protein,...    false
# 2      Trichoplusia ni multiple nucleopolyhedrovirus|...    false
# 3                                                    NaN    false
# 4                                                    NaN    false
# ...                                                  ...      ...
# 87269                                         Mag-indo-1    false
# 87270                      Yor162c protein, S cerevisiae    false
# 87271                                   3-epiactinobolin    false
# 87272                                                NaN    false
# 87273                                                NaN      NaN
#
#                               CUI  \
# 0                        C0305030
# 1      C3714068|C3714069|C3711174
# 2                        C1629281
# 3                        C1623861
# 4                        C0067922
# ...                           ...
# 87269           C0257751|C0257752
# 87270                    C1434606
# 87271                    C0673839
# 87272                    C4045127
# 87273                         NaN
#
#                                           Semantic Types
# 0      http://purl.bioontology.org/ontology/STY/T130|...
# 1      http://purl.bioontology.org/ontology/STY/T123|...
# 2          http://purl.bioontology.org/ontology/STY/T005
# 3          http://purl.bioontology.org/ontology/STY/T007
# 4          http://purl.bioontology.org/ontology/STY/T109
# ...                                                  ...
# 87269  http://purl.bioontology.org/ontology/STY/T109|...
# 87270      http://purl.bioontology.org/ontology/STY/T116
# 87271      http://purl.bioontology.org/ontology/STY/T109
# 87272      http://purl.bioontology.org/ontology/STY/T109
# 87273                                                NaN
#
# [87274 rows x 6 columns]

# %%
mesh_df['Class ID'] = mesh_df['Class ID'].apply(lambda x: x.split('/')[-1])

# %%
print(mesh_df.shape)
# Out:
# (87274, 6)

# %%
mesh_df = mesh_df[mesh_df['Obsolete']=='false']
mesh_df = mesh_df.drop('Obsolete',axis=1)
print(mesh_df.shape)
# Out:
# (87273, 5)

# %%
mesh_df[['ST1','ST2']] = mesh_df['Semantic Types'].str.split('|', 1, expand=True)
mesh_df[['ST2','ST3']] = mesh_df['ST2'].str.split('|', 1, expand=True)
mesh_df
# Out:
#          Class ID                                    Preferred Label  \
# 0      C000624633       technetium 99m hydroxyethylene-diphosphonate
# 1         C585345                          Tardbp protein, zebrafish
# 2      C000623720  Autographa californica multiple nuclear polyhe...
# 3      C000644313                        Leeuwenhoekiella blandensis
# 4         C049340                                N-demethylmenogaril
# ...           ...                                                ...
# 87268     C503576  bis di-N,N'-1-deoxyfructosyl glutathione disul...
# 87269     C088692  2-(4-(biscarboxymethyl)amino-3-(carboxymethoxy...
# 87270     C481277                         Yrr1 protein, S cerevisiae
# 87271     C111764                                  3-epi-actinobolin
# 87272  C000595691                    2-tridecanyl-1,4-naphthoquinone
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      Tardbpl-FL protein, zebrafish|Tardbpl protein,...
# 2      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 87268         bis di-N,N'-1-deoxyfructosyl GSSG|F-GSSG-F
# 87269                                         Mag-indo-1
# 87270                      Yor162c protein, S cerevisiae
# 87271                                   3-epiactinobolin
# 87272                                                NaN
#
#                               CUI  \
# 0                        C0305030
# 1      C3714068|C3714069|C3711174
# 2                        C1629281
# 3                        C1623861
# 4                        C0067922
# ...                           ...
# 87268                    C1611461
# 87269           C0257751|C0257752
# 87270                    C1434606
# 87271                    C0673839
# 87272                    C4045127
#
#                                           Semantic Types  \
# 0      http://purl.bioontology.org/ontology/STY/T130|...
# 1      http://purl.bioontology.org/ontology/STY/T123|...
# 2          http://purl.bioontology.org/ontology/STY/T005
# 3          http://purl.bioontology.org/ontology/STY/T007
# 4          http://purl.bioontology.org/ontology/STY/T109
# ...                                                  ...
# 87268  http://purl.bioontology.org/ontology/STY/T116|...
# 87269  http://purl.bioontology.org/ontology/STY/T109|...
# 87270      http://purl.bioontology.org/ontology/STY/T116
# 87271      http://purl.bioontology.org/ontology/STY/T109
# 87272      http://purl.bioontology.org/ontology/STY/T109
#
#                                                  ST1  \
# 0      http://purl.bioontology.org/ontology/STY/T130
# 1      http://purl.bioontology.org/ontology/STY/T123
# 2      http://purl.bioontology.org/ontology/STY/T005
# 3      http://purl.bioontology.org/ontology/STY/T007
# 4      http://purl.bioontology.org/ontology/STY/T109
# ...                                              ...
# 87268  http://purl.bioontology.org/ontology/STY/T116
# 87269  http://purl.bioontology.org/ontology/STY/T109
# 87270  http://purl.bioontology.org/ontology/STY/T116
# 87271  http://purl.bioontology.org/ontology/STY/T109
# 87272  http://purl.bioontology.org/ontology/STY/T109
#
#                                                  ST2   ST3
# 0      http://purl.bioontology.org/ontology/STY/T197  None
# 1      http://purl.bioontology.org/ontology/STY/T116  None
# 2                                               None  None
# 3                                               None  None
# 4                                               None  None
# ...                                              ...   ...
# 87268  http://purl.bioontology.org/ontology/STY/T121  None
# 87269  http://purl.bioontology.org/ontology/STY/T121  None
# 87270                                           None  None
# 87271                                           None  None
# 87272                                           None  None
#
# [87273 rows x 8 columns]

# %%
mesh_df = mesh_df.drop('Semantic Types',axis=1)

# %%
mesh_df.sample(10)
# Out:
#          Class ID                         Preferred Label  \
# 33850     C487100                chn-1 protein, C elegans
# 80619     C080578                         lysyl-gingivain
# 1250   C000644242                  Microbispora siamensis
# 25429     C553777                                sedinine
# 17584     C557792                  USP12 protein, Xenopus
# 74855  C000627664                    PHF14 protein, human
# 27466     C554600              Grh1 protein, S cerevisiae
# 30175     D019916  Choline-Phosphate Cytidylyltransferase
# 83913     C408478                       3-C-methylmannose
# 9955      C491450                  prp31 protein, S pombe
#
#                                                 Synonyms                CUI  \
# 33850  C-terminus of Hsc70 interacting protein, C ele...           C1452731
# 80619                                      Lys-gingivain           C0658284
# 1250                                                 NaN           C3716101
# 25429                                                NaN           C2973961
# 17584                                                NaN           C3180903
# 74855                       PHD finger protein 14, human           C4706076
# 27466                                                NaN           C2973348
# 30175  CTP Phosphocholine Cytidylyltransferase|Cytidy...           C0311989
# 83913                               3-C-methyl-D-mannose  C0914454|C0914455
# 9955                        SPBC119.13c protein, S pombe           C1434051
#
#                                                  ST1  \
# 33850  http://purl.bioontology.org/ontology/STY/T126
# 80619  http://purl.bioontology.org/ontology/STY/T126
# 1250   http://purl.bioontology.org/ontology/STY/T007
# 25429  http://purl.bioontology.org/ontology/STY/T109
# 17584  http://purl.bioontology.org/ontology/STY/T126
# 74855  http://purl.bioontology.org/ontology/STY/T123
# 27466  http://purl.bioontology.org/ontology/STY/T123
# 30175  http://purl.bioontology.org/ontology/STY/T126
# 83913  http://purl.bioontology.org/ontology/STY/T109
# 9955   http://purl.bioontology.org/ontology/STY/T123
#
#                                                  ST2   ST3
# 33850  http://purl.bioontology.org/ontology/STY/T116  None
# 80619  http://purl.bioontology.org/ontology/STY/T116  None
# 1250                                            None  None
# 25429                                           None  None
# 17584  http://purl.bioontology.org/ontology/STY/T116  None
# 74855  http://purl.bioontology.org/ontology/STY/T116  None
# 27466  http://purl.bioontology.org/ontology/STY/T116  None
# 30175  http://purl.bioontology.org/ontology/STY/T116  None
# 83913                                           None  None
# 9955   http://purl.bioontology.org/ontology/STY/T116  None

# %%
def set_specific_type(type_x,type_y,type_z):
    if not pd.isnull(type_z):
        return type_z
    if not pd.isnull(type_y):
        return type_y
    return type_x

# %%
mesh_df['ST'] = mesh_df.apply(lambda x: set_specific_type(x.ST1,x.ST2,x.ST3),axis=1)

# %%
mesh_df = mesh_df.drop(['ST1','ST2','ST3'],axis=1)
mesh_df
# Out:
#          Class ID                                    Preferred Label  \
# 0      C000624633       technetium 99m hydroxyethylene-diphosphonate
# 1         C585345                          Tardbp protein, zebrafish
# 2      C000623720  Autographa californica multiple nuclear polyhe...
# 3      C000644313                        Leeuwenhoekiella blandensis
# 4         C049340                                N-demethylmenogaril
# ...           ...                                                ...
# 87268     C503576  bis di-N,N'-1-deoxyfructosyl glutathione disul...
# 87269     C088692  2-(4-(biscarboxymethyl)amino-3-(carboxymethoxy...
# 87270     C481277                         Yrr1 protein, S cerevisiae
# 87271     C111764                                  3-epi-actinobolin
# 87272  C000595691                    2-tridecanyl-1,4-naphthoquinone
#
#                                                 Synonyms  \
# 0          99mTc-HDP|99mTc-hydroxyethylene-diphosphonate
# 1      Tardbpl-FL protein, zebrafish|Tardbpl protein,...
# 2      Trichoplusia ni multiple nucleopolyhedrovirus|...
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 87268         bis di-N,N'-1-deoxyfructosyl GSSG|F-GSSG-F
# 87269                                         Mag-indo-1
# 87270                      Yor162c protein, S cerevisiae
# 87271                                   3-epiactinobolin
# 87272                                                NaN
#
#                               CUI  \
# 0                        C0305030
# 1      C3714068|C3714069|C3711174
# 2                        C1629281
# 3                        C1623861
# 4                        C0067922
# ...                           ...
# 87268                    C1611461
# 87269           C0257751|C0257752
# 87270                    C1434606
# 87271                    C0673839
# 87272                    C4045127
#
#                                                   ST
# 0      http://purl.bioontology.org/ontology/STY/T197
# 1      http://purl.bioontology.org/ontology/STY/T116
# 2      http://purl.bioontology.org/ontology/STY/T005
# 3      http://purl.bioontology.org/ontology/STY/T007
# 4      http://purl.bioontology.org/ontology/STY/T109
# ...                                              ...
# 87268  http://purl.bioontology.org/ontology/STY/T121
# 87269  http://purl.bioontology.org/ontology/STY/T121
# 87270  http://purl.bioontology.org/ontology/STY/T116
# 87271  http://purl.bioontology.org/ontology/STY/T109
# 87272  http://purl.bioontology.org/ontology/STY/T109
#
# [87273 rows x 5 columns]

# %% [markdown]
# ## Semantic Types

# %%
semantic_type_df = pd.read_csv(
    "data/STY.csv",      # relative python path to subdirectory
    sep=',',
    dtype=str,
    usecols=['Class ID','Preferred Label']
)
semantic_type_df
# Out:
#                                           Class ID  \
# 0    http://purl.bioontology.org/ontology/STY/T057
# 1    http://purl.bioontology.org/ontology/STY/T047
# 2    http://purl.bioontology.org/ontology/STY/T167
# 3    http://purl.bioontology.org/ontology/STY/T066
# 4    http://purl.bioontology.org/ontology/STY/T184
# ..                                             ...
# 122  http://purl.bioontology.org/ontology/STY/T194
# 123  http://purl.bioontology.org/ontology/STY/T012
# 124  http://purl.bioontology.org/ontology/STY/T087
# 125  http://purl.bioontology.org/ontology/STY/T122
# 126  http://purl.bioontology.org/ontology/STY/T197
#
#                    Preferred Label
# 0            Occupational Activity
# 1              Disease or Syndrome
# 2                        Substance
# 3                 Machine Activity
# 4                  Sign or Symptom
# ..                             ...
# 122                       Archaeon
# 123                           Bird
# 124            Amino Acid Sequence
# 125  Biomedical or Dental Material
# 126             Inorganic Chemical
#
# [127 rows x 2 columns]

# %%
semantic_type_df.rename(columns={'Class ID': 'Semantic_type_url','Preferred Label':'type'}, inplace=True)

# %%
mesh_df = pd.merge(mesh_df,semantic_type_df,left_on='ST',right_on='Semantic_type_url',how='inner')

# %%
print(mesh_df.shape)
# Out:
# (87079, 7)

# %%
mesh_df.sample(10)
# Out:
#          Class ID                           Preferred Label  \
# 51559     C413035                             malyngamide R
# 7998      C098314  HIV envelope glycoprotein gp41 (593-603)
# 31304  C000641142                       Thiocapsa litoralis
# 65040     C041753     beta-cyanoethyl phosphorodichloridite
# 61921     C096023                          ardisiaquinone D
# 23673     C509306                     CRIPAK protein, human
# 28095  C000647950                    Acidocella aminolytica
# 21456  C000607606                      cheY protein, E coli
# 6297      C478492                  slif protein, Drosophila
# 74160     D011657                    Pulmonary Eosinophilia
#
#                                                 Synonyms  \
# 51559                                                NaN
# 7998   glycoprotein 41 (593-603), HIV|gp41 (593-603),...
# 31304                                                NaN
# 65040  Phosphorodichloridous acid, 2-(((3alpha,5beta)...
# 61921                                                NaN
# 23673  cysteine-rich PAK1 inhibitor, human|cysteine-r...
# 28095  Acidiphilium aminilyticum|Acidiphilium aminoly...
# 21456                       chemotaxis Y protein, E coli
# 6297                        Slimfast protein, Drosophila
# 74160  Eosinophilic Pneumonia, Tropical|Pneumonia, Eo...
#
#                                        CUI  \
# 51559                             C0960625
# 7998                              C0387205
# 31304                             C1187842
# 65040                             C0621583
# 61921                             C0382358
# 23673                             C1698863
# 28095                             C1004820
# 21456                             C4307955
# 6297                              C1312854
# 74160  C0242459|C0034068|C2350879|C1527407
#
#                                                   ST  \
# 51559  http://purl.bioontology.org/ontology/STY/T109
# 7998   http://purl.bioontology.org/ontology/STY/T116
# 31304  http://purl.bioontology.org/ontology/STY/T007
# 65040  http://purl.bioontology.org/ontology/STY/T121
# 61921  http://purl.bioontology.org/ontology/STY/T121
# 23673  http://purl.bioontology.org/ontology/STY/T116
# 28095  http://purl.bioontology.org/ontology/STY/T007
# 21456  http://purl.bioontology.org/ontology/STY/T116
# 6297   http://purl.bioontology.org/ontology/STY/T116
# 74160  http://purl.bioontology.org/ontology/STY/T047
#
#                                    Semantic_type_url  \
# 51559  http://purl.bioontology.org/ontology/STY/T109
# 7998   http://purl.bioontology.org/ontology/STY/T116
# 31304  http://purl.bioontology.org/ontology/STY/T007
# 65040  http://purl.bioontology.org/ontology/STY/T121
# 61921  http://purl.bioontology.org/ontology/STY/T121
# 23673  http://purl.bioontology.org/ontology/STY/T116
# 28095  http://purl.bioontology.org/ontology/STY/T007
# 21456  http://purl.bioontology.org/ontology/STY/T116
# 6297   http://purl.bioontology.org/ontology/STY/T116
# 74160  http://purl.bioontology.org/ontology/STY/T047
#
#                                   type
# 51559                 Organic Chemical
# 7998   Amino Acid, Peptide, or Protein
# 31304                        Bacterium
# 65040          Pharmacologic Substance
# 61921          Pharmacologic Substance
# 23673  Amino Acid, Peptide, or Protein
# 28095                        Bacterium
# 21456  Amino Acid, Peptide, or Protein
# 6297   Amino Acid, Peptide, or Protein
# 74160              Disease or Syndrome

# %%
mesh_df.columns
# Out:
# Index(['Class ID', 'Preferred Label', 'Synonyms', 'ST1', 'ST2', 'ST3',
#        'Semantic_type_url_x', 'type_x', 'Semantic_type_url_y', 'type_y',
#        'Semantic_type_url', 'type'],
#       dtype='object')

# %%
mesh_df= mesh_df[['Class ID','Preferred Label','Synonyms','CUI','type']]

# %%
mesh_df.sample(10)
# Out:
#       Class ID                                    Preferred Label  \
# 71194  C074658  9-(c-4,t-5-bis(hydroxymethyl)cyclopent-2-en-r-...
# 47674  C006817           7-bromo-7,8-didemethyl-8-ethylriboflavin
# 36266  C557382  2beta,5alpha,15beta-O-triacetoxy-3beta-O-nicot...
# 72256  C114802                                  10-oximeguanacone
# 55566  C078279  17-acetoxy-3-(glucopyransosyl)oxy-6-methylpreg...
# 11856  C544060                                 Acd protein, mouse
# 19318  C081536                  glutathionylspermidine synthetase
# 32327  C014566  17 beta-(3-furyl)-5 beta,14 beta-androstane-3 ...
# 38753  C556254  (1,4-dimethoxynaphthalen-2-yl)(2-hydroxyphenyl...
# 9119   C079187        Ttm protein, Equine infectious anemia virus
#
#                                                 Synonyms                CUI  \
# 71194                                   BOHMe-cp-adenine           C0651651
# 47674  7-bromo-8-ethylriboflavin|7-bromo-8-ethyl-10-(...  C0602882|C0602881
# 36266                                       TA-N-OEE cpd           C3180594
# 72256                                                NaN           C0758181
# 55566  17-AGOMP|17 alpha-acetoxy-3 beta-((beta-D-gluc...           C0655704
# 11856  adrenocortical dysplasia homolog (mouse) prote...           C2743589
# 19318                                  GSH-SP synthetase           C0216884
# 32327  24-Norchola-20,22-diene-3,14-diol, 21,23-epoxy...           C0606251
# 38753                                                NaN           C3179913
# 9119                                                 NaN           C0656763
#
#                                   type
# 71194          Pharmacologic Substance
# 47674                 Organic Chemical
# 36266                 Organic Chemical
# 72256          Pharmacologic Substance
# 55566                 Organic Chemical
# 11856  Amino Acid, Peptide, or Protein
# 19318  Amino Acid, Peptide, or Protein
# 32327                 Organic Chemical
# 38753                 Organic Chemical
# 9119   Amino Acid, Peptide, or Protein

# %%
mesh_df.isnull().sum(axis = 0)
# Out:
# Class ID               0
# Preferred Label        0
# Synonyms           28522
# CUI                    0
# type                   0
# dtype: int64

# %%
mesh_df.to_csv('data/MESH_with_Semantic_types.csv',index=False)
