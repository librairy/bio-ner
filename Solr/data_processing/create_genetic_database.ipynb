# %%
import pandas as pd 
import numpy as np

# %%
def set_term(column1,column2):
    if not pd.isnull(column1):
        return column1
    if not pd.isnull(column2):
        return column2
    else:
        return np.nan

# %%
def separate_id(column,idx):
    for i in column:
        if idx in i:
            column.remove(i)
            if idx == 'UniProtKB' or idx == 'NCBIGene':
                return i.split(':')[-1]
            return i
    return np.nan

# %%
pd.options.mode.chained_assignment = None

# %% [markdown]
# # Gene Ontology

# %%
important_columns_go = ['Class ID','Preferred Label','Synonyms','Obsolete','database_cross_reference','has_obo_namespace']

# %%
go_df = pd.read_csv('data/Genetic/GO.csv', usecols=important_columns_go, dtype=str)
go_df
# Out:
#                                         Class ID  \
# 0      http://purl.obolibrary.org/obo/GO_0015219
# 1      http://purl.obolibrary.org/obo/GO_1902084
# 2      http://purl.obolibrary.org/obo/GO_0106291
# 3      http://purl.obolibrary.org/obo/GO_1903896
# 4      http://purl.obolibrary.org/obo/GO_0051203
# ...                                          ...
# 50600  http://purl.obolibrary.org/obo/GO_0019508
# 50601  http://purl.obolibrary.org/obo/GO_0034378
# 50602  http://purl.obolibrary.org/obo/GO_0070362
# 50603  http://purl.obolibrary.org/obo/GO_0050239
# 50604  http://purl.obolibrary.org/obo/GO_0050310
#
#                                          Preferred Label  \
# 0      obsolete protein-DNA complex transmembrane tra...
# 1                           fumagillin metabolic process
# 2           superoxide-generating NADH oxidase activity.
# 3      positive regulation of IRE1-mediated unfolded ...
# 4      peptidyl-aspartic acid reduction to form L-asp...
# ...                                                  ...
# 50600  2,5-dihydroxypyridine catabolic process to fum...
# 50601                               chylomicron assembly
# 50602                                         GO_0070362
# 50603                    pyrithiamine deaminase activity
# 50604                     sulfite dehydrogenase activity
#
#                                                 Synonyms Obsolete  \
# 0      DNA-protein complex transmembrane transporter ...     true
# 1                                  fumagillin metabolism    false
# 2                                                    NaN    false
# 3      upregulation of UPR signaling by IRE1 stress s...    false
# 4      peptidyl-aspartic acid reduction to form L-asp...    false
# ...                                                  ...      ...
# 50600  2,5-dihydroxypyridine breakdown to fumarate|py...    false
# 50601                                                NaN    false
# 50602                                                NaN     true
# 50603  1-(4-amino-2-methylpyrimid-5-ylmethyl)-3-(beta...    false
# 50604  sulphite dehydrogenase activity|sulfite:ferric...    false
#
#                                 database_cross_reference   has_obo_namespace
# 0                                                    NaN  molecular_function
# 1                                                    NaN  biological_process
# 2                                             RHEA:63184  molecular_function
# 3                                                    NaN  biological_process
# 4                                           RESID:AA0373  biological_process
# ...                                                  ...                 ...
# 50600                                    MetaCyc:PWY-722  biological_process
# 50601                                                NaN  biological_process
# 50602                                                NaN                 NaN
# 50603  RHEA:14537|MetaCyc:PYRITHIAMIN-DEAMINASE-RXN|E...  molecular_function
# 50604  MetaCyc:SULFITE-DEHYDROGENASE-RXN|EC:1.8.2.1|R...  molecular_function
#
# [50605 rows x 6 columns]

# %%
go_df = go_df[go_df['Obsolete']=='false']
go_df.drop('Obsolete',inplace=True,axis=1)
print(go_df.shape)
# Out:
# (43987, 5)

# %%
go_df['GO_id'] = go_df['Class ID'].apply(lambda x: x.split('/')[-1].split('_')[-1] if isinstance(x,str) else np.nan)
go_df.drop('Class ID',inplace=True,axis=1)

# %%
go_df.rename(columns={'Preferred Label':'Term','database_cross_reference':'cross_reference'},inplace=True)

# %%
go_df['Synonyms'] = go_df['Synonyms'].apply(lambda x: [f for f in x.split('|')] if isinstance(x,str) else np.nan)

# %%
go_df['cross_reference'] = go_df['cross_reference'].apply(lambda x: [f for f in x.split('|')] if isinstance(x,str) else np.nan)

# %%
go_df['type'] = go_df['has_obo_namespace'].apply(lambda x: x.replace('_',' ') if isinstance(x,str) else np.nan)

# %%
go_df.drop('has_obo_namespace',inplace=True,axis=1)

# %%
go_df
# Out:
#                                                     Term  \
# 1                           fumagillin metabolic process
# 2           superoxide-generating NADH oxidase activity.
# 3      positive regulation of IRE1-mediated unfolded ...
# 4      peptidyl-aspartic acid reduction to form L-asp...
# 6      negative regulation of planar cell polarity pa...
# ...                                                  ...
# 50597  negative regulation of ribosomal large subunit...
# 50600  2,5-dihydroxypyridine catabolic process to fum...
# 50601                               chylomicron assembly
# 50603                    pyrithiamine deaminase activity
# 50604                     sulfite dehydrogenase activity
#
#                                                 Synonyms  \
# 1                                [fumagillin metabolism]
# 2                                                    NaN
# 3      [upregulation of UPR signaling by IRE1 stress ...
# 4      [peptidyl-aspartic acid reduction to form L-as...
# 6                                                    NaN
# ...                                                  ...
# 50597  [negative regulation of ribosomal large subuni...
# 50600  [2,5-dihydroxypyridine breakdown to fumarate, ...
# 50601                                                NaN
# 50603  [1-(4-amino-2-methylpyrimid-5-ylmethyl)-3-(bet...
# 50604  [sulphite dehydrogenase activity, sulfite:ferr...
#
#                                          cross_reference    GO_id  \
# 1                                                    NaN  1902084
# 2                                           [RHEA:63184]  0106291
# 3                                                    NaN  1903896
# 4                                         [RESID:AA0373]  0051203
# 6                                                    NaN  2000149
# ...                                                  ...      ...
# 50597                                                NaN  2000204
# 50600                                  [MetaCyc:PWY-722]  0019508
# 50601                                                NaN  0034378
# 50603  [RHEA:14537, MetaCyc:PYRITHIAMIN-DEAMINASE-RXN...  0050239
# 50604  [MetaCyc:SULFITE-DEHYDROGENASE-RXN, EC:1.8.2.1...  0050310
#
#                      type
# 1      biological process
# 2      molecular function
# 3      biological process
# 4      biological process
# 6      biological process
# ...                   ...
# 50597  biological process
# 50600  biological process
# 50601  biological process
# 50603  molecular function
# 50604  molecular function
#
# [43987 rows x 5 columns]

# %% [markdown]
# # Ontology of Genes and Genomes

# %%
important_columns_ogg = ['Preferred Label','Synonyms','Obsolete','database_cross_reference','full name from nomenclature authority','type of gene','NCBI GeneID','organism NCBITaxon ID']

# %%
ogg_df = pd.read_csv('data/Genetic/OGG.csv', usecols=important_columns_ogg, dtype=str)
ogg_df
# Out:
#       Preferred Label                              Synonyms Obsolete  \
# 0            NDUFB3P5                                   NaN    false
# 1            RPL34P13                           RPL34_3_616    false
# 2               EFNB3                      EPLG8|EFL6|LERK8    false
# 3              MIR532                   MIRN532|hsa-mir-532    false
# 4               GTSF1                               FAM112B    false
# ...               ...                                   ...      ...
# 69683            mdlB                    mdl|JW5061|ECK0443    false
# 69684       RVBD_0838                                   NaN    false
# 69685        SNORD62A                        U62A|RNU62|U62    false
# 69686    LOC101928500                                   NaN    false
# 69687            SNW1  Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP    false
#
#                                 database_cross_reference  \
# 0                                                    NaN
# 1                                             HGNC:36398
# 2      HGNC:3228|Ensembl:ENSG00000108947|Vega:OTTHUMG...
# 3                           HGNC:32795|miRBase:MI0003205
# 4      HPRD:08150|Ensembl:ENSG00000170627|Vega:OTTHUM...
# ...                                                  ...
# 69683                                    EcoGene:EG14374
# 69684                                                NaN
# 69685                                         HGNC:10219
# 69686                                                NaN
# 69687  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#                    full name from nomenclature authority NCBI GeneID  \
# 0      NADH dehydrogenase (ubiquinone) 1 beta subcomp...       93997
# 1                    ribosomal protein L34 pseudogene 13   100270997
# 2                                              ephrin-B3        1949
# 3                                           microRNA 532      693124
# 4                           gametocyte specific factor 1      121355
# ...                                                  ...         ...
# 69683                                                NaN      945088
# 69684                                                NaN    13318740
# 69685                   small nucleolar RNA, C/D box 62A       26786
# 69686                                                NaN   101928500
# 69687                            SNW domain containing 1       22938
#
#       organism NCBITaxon ID    type of gene
# 0                      9606          pseudo
# 1                      9606          pseudo
# 2                      9606  protein-coding
# 3                      9606           ncRNA
# 4                      9606  protein-coding
# ...                     ...             ...
# 69683                511145  protein-coding
# 69684                 83332  protein-coding
# 69685                  9606          snoRNA
# 69686                  9606           ncRNA
# 69687                  9606  protein-coding
#
# [69688 rows x 8 columns]

# %%
ogg_df = ogg_df[ogg_df['Obsolete']=='false']
ogg_df.drop('Obsolete',inplace=True,axis=1)
print(ogg_df.shape)
# Out:
# (69688, 7)

# %%
ogg_df
# Out:
#       Preferred Label                              Synonyms  \
# 0            NDUFB3P5                                   NaN
# 1            RPL34P13                           RPL34_3_616
# 2               EFNB3                      EPLG8|EFL6|LERK8
# 3              MIR532                   MIRN532|hsa-mir-532
# 4               GTSF1                               FAM112B
# ...               ...                                   ...
# 69683            mdlB                    mdl|JW5061|ECK0443
# 69684       RVBD_0838                                   NaN
# 69685        SNORD62A                        U62A|RNU62|U62
# 69686    LOC101928500                                   NaN
# 69687            SNW1  Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP
#
#                                 database_cross_reference  \
# 0                                                    NaN
# 1                                             HGNC:36398
# 2      HGNC:3228|Ensembl:ENSG00000108947|Vega:OTTHUMG...
# 3                           HGNC:32795|miRBase:MI0003205
# 4      HPRD:08150|Ensembl:ENSG00000170627|Vega:OTTHUM...
# ...                                                  ...
# 69683                                    EcoGene:EG14374
# 69684                                                NaN
# 69685                                         HGNC:10219
# 69686                                                NaN
# 69687  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#                    full name from nomenclature authority NCBI GeneID  \
# 0      NADH dehydrogenase (ubiquinone) 1 beta subcomp...       93997
# 1                    ribosomal protein L34 pseudogene 13   100270997
# 2                                              ephrin-B3        1949
# 3                                           microRNA 532      693124
# 4                           gametocyte specific factor 1      121355
# ...                                                  ...         ...
# 69683                                                NaN      945088
# 69684                                                NaN    13318740
# 69685                   small nucleolar RNA, C/D box 62A       26786
# 69686                                                NaN   101928500
# 69687                            SNW domain containing 1       22938
#
#       organism NCBITaxon ID    type of gene
# 0                      9606          pseudo
# 1                      9606          pseudo
# 2                      9606  protein-coding
# 3                      9606           ncRNA
# 4                      9606  protein-coding
# ...                     ...             ...
# 69683                511145  protein-coding
# 69684                 83332  protein-coding
# 69685                  9606          snoRNA
# 69686                  9606           ncRNA
# 69687                  9606  protein-coding
#
# [69688 rows x 7 columns]

# %% [markdown]
# # Protein Ontology

# %%
important_columns_pr = ['Preferred Label','Synonyms','Obsolete','database_cross_reference','http://www.geneontology.org/formats/oboInOwl#id','only_in_taxon','http://www.w3.org/2000/01/rdf-schema#comment']

# %%
pr_df = pd.read_csv('data/Genetic/PR.csv', usecols=important_columns_pr, dtype=str)
pr_df
# Out:
#                                           Preferred Label  \
# 0       solute carrier organic anion transporter famil...
# 1                            trbG (Escherichia coli K-12)
# 2       interleukin enhancer-binding factor 2 isoform ...
# 3       gag-pol polyprotein (Human immunodeficiency vi...
# 4       serine/threonine-protein kinase MRCK alpha iso...
# ...                                                   ...
# 331975              diamine acetyltransferase 1 (chicken)
# 331976    synaptophysin-like protein 1 isoform m2 (mouse)
# 331977                      zinc finger protein 3 homolog
# 331978                        RKD2 (Arabidopsis thaliana)
# 331979                    zinc finger RNA-binding protein
#
#                                                  Synonyms Obsolete  \
# 0                                         hSLCO3A1/iso:h3    false
# 1                                                     NaN    false
# 2                                             mILF2/iso:1    false
# 3       Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...    false
# 4                                        hCDC42BPA/iso:h6    false
# ...                                                   ...      ...
# 331975  SSAT-1 (chicken)|putrescine acetyltransferase ...    false
# 331976                                      mSYPL1/iso:m2    false
# 331977                                  ZFP3|zfp-3|ZNF752    false
# 331978                                                NaN    false
# 331979                 M-phase phosphoprotein homolog|ZFR    false
#
#        database_cross_reference  \
# 0            UniProtKB:Q9UIG8-3
# 1                           NaN
# 2            UniProtKB:Q9CXY6-1
# 3              UniProtKB:P12499
# 4            UniProtKB:Q5VT25-6
# ...                         ...
# 331975         UniProtKB:Q8AXL1
# 331976       UniProtKB:O09117-2
# 331977                      NaN
# 331978                      NaN
# 331979                      NaN
#
#        http://www.geneontology.org/formats/oboInOwl#id  \
# 0                                          PR:Q9UIG8-3
# 1                                     NCBIGene:1263580
# 2                                          PR:Q9CXY6-1
# 3                                            PR:P12499
# 4                                          PR:Q5VT25-6
# ...                                                ...
# 331975                                       PR:Q8AXL1
# 331976                                     PR:O09117-2
# 331977                                    PR:000017637
# 331978                               Araport:AT1G74480
# 331979                                    PR:000017654
#
#        http://www.w3.org/2000/01/rdf-schema#comment  \
# 0                       Category=organism-sequence.
# 1                                Category=external.
# 2                       Category=organism-sequence.
# 3                           Category=organism-gene.
# 4                       Category=organism-sequence.
# ...                                             ...
# 331975                      Category=organism-gene.
# 331976                  Category=organism-sequence.
# 331977                               Category=gene.
# 331978                           Category=external.
# 331979                               Category=gene.
#
#                                          only_in_taxon
# 0        http://purl.obolibrary.org/obo/NCBITaxon_9606
# 1       http://purl.obolibrary.org/obo/NCBITaxon_83333
# 2       http://purl.obolibrary.org/obo/NCBITaxon_10090
# 3       http://purl.obolibrary.org/obo/NCBITaxon_11683
# 4        http://purl.obolibrary.org/obo/NCBITaxon_9606
# ...                                                ...
# 331975   http://purl.obolibrary.org/obo/NCBITaxon_9031
# 331976  http://purl.obolibrary.org/obo/NCBITaxon_10090
# 331977                                             NaN
# 331978   http://purl.obolibrary.org/obo/NCBITaxon_3702
# 331979                                             NaN
#
# [331980 rows x 7 columns]

# %%
pr_df = pr_df[pr_df['Obsolete']=='false']
pr_df.drop('Obsolete',inplace=True,axis=1)
print(pr_df.shape)
# Out:
# (326674, 6)

# %%
renamed_pr = {'Preferred Label':'Term','database_cross_reference':'cross_reference','http://www.geneontology.org/formats/oboInOwl#id':'id','only_in_taxon':'taxon_id','http://www.w3.org/2000/01/rdf-schema#comment':'type_of_ent'}
pr_df = pr_df.rename(columns=renamed_pr)

# %%
pr_df['taxon_id'] = pr_df['taxon_id'].apply(lambda x: x.split('/')[-1].split('_')[-1] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x[x.find('Category=') + len('Category='):] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x.split('.')[0] if isinstance(x,str) else np.nan)

# %%
pr_df['type_of_ent'] = pr_df['type_of_ent'].apply(lambda x: x.replace('-',' ') if isinstance(x,str) else np.nan)

# %%
pr_df['cross_reference'] = pr_df['cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan)

# %%
pr_df['UniprotID'] = pr_df.apply(lambda x: separate_id(x.cross_reference,'UniProtKB') if isinstance(x.cross_reference,list) else np.nan,axis=1)

# %%
pr_df['NCBI_id'] = pr_df['id'].apply(lambda x: x.split(':')[-1] if x.startswith('NCBIGene') else np.nan)

# %%
pr_df.count()
# Out:
# Term               326674
# Synonyms           224830
# cross_reference    178542
# id                 326674
# type_of_ent        324708
# taxon_id           287437
# UniprotID          170646
# NCBI_id              5380
# dtype: int64

# %%
pr_df.sample(10)
# Out:
#                                                      Term  \
# 297340  peroxisome proliferator-activated receptor gam...
# 33368                      protein TFG isoform h1 (human)
# 34245   60S ribosomal protein L15-1 (Arabidopsis thali...
# 203467                              LOC560371 (zebrafish)
# 9422    polyadenylate-binding protein, cytoplasmic and...
# 74331   serine/threonine-protein kinase PBL13 (Arabido...
# 299480  protein arginine N-methyltransferase SFM1 (yeast)
# 59233             carbohydrate sulfotransferase 1 (mouse)
# 260124                   ogm1 (Schizosaccharomyces pombe)
# 26541   QWRF motif-containing protein 6 isoform 1 (Ara...
#
#                                                  Synonyms cross_reference  \
# 297340                                      rPPARG/iso:r1              []
# 33368                                         hTFG/iso:h1              []
# 34245       At-RPL15A|RPL15A|At4g16720|FCAALL.416|dl4385c              []
# 203467                                                NaN             NaN
# 9422    Spom972h-pab1(SPAC57A7.04c)|polyadenylate tail...              []
# 74331   At-PBL13|ser/Thr protein kinase ACIK1b (Arabid...              []
# 299480  ySFM1|SPOUT family methyltransferase 1 (yeast)...              []
# 59233   keratan sulfate Gal-6 sulfotransferase (mouse)...              []
# 260124                                                NaN             NaN
# 26541                                      At-QWRF6/iso:1              []
#
#                            id        type_of_ent taxon_id UniprotID NCBI_id
# 297340            PR:O88275-2  organism sequence    10116  O88275-2     NaN
# 33368             PR:Q92734-1  organism sequence     9606  Q92734-1     NaN
# 34245               PR:O23515      organism gene     3702    O23515     NaN
# 203467        NCBIGene:560371           external     7955       NaN  560371
# 9422                PR:P31209      organism gene   284812    P31209     NaN
# 74331               PR:F4JZW1      organism gene     3702    F4JZW1     NaN
# 299480              PR:Q12314      organism gene   559292    Q12314     NaN
# 59233               PR:Q9EQC0      organism gene    10090    Q9EQC0     NaN
# 260124  PomBase:SPAC22A12.07c           external     4896       NaN     NaN
# 26541             PR:Q5BPM6-1  organism sequence     3702  Q5BPM6-1     NaN

# %%
pr_df.rename(columns={'NCBI_id':'NCBI GeneID'},inplace=True)

# %%
pr_df
# Out:
#                                                      Term  \
# 0       solute carrier organic anion transporter famil...
# 1                            trbG (Escherichia coli K-12)
# 2       interleukin enhancer-binding factor 2 isoform ...
# 3       gag-pol polyprotein (Human immunodeficiency vi...
# 4       serine/threonine-protein kinase MRCK alpha iso...
# ...                                                   ...
# 331975              diamine acetyltransferase 1 (chicken)
# 331976    synaptophysin-like protein 1 isoform m2 (mouse)
# 331977                      zinc finger protein 3 homolog
# 331978                        RKD2 (Arabidopsis thaliana)
# 331979                    zinc finger RNA-binding protein
#
#                                                  Synonyms cross_reference  \
# 0                                         hSLCO3A1/iso:h3              []
# 1                                                     NaN             NaN
# 2                                             mILF2/iso:1              []
# 3       Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                        hCDC42BPA/iso:h6              []
# ...                                                   ...             ...
# 331975  SSAT-1 (chicken)|putrescine acetyltransferase ...              []
# 331976                                      mSYPL1/iso:m2              []
# 331977                                  ZFP3|zfp-3|ZNF752             NaN
# 331978                                                NaN             NaN
# 331979                 M-phase phosphoprotein homolog|ZFR             NaN
#
#                        id        type_of_ent taxon_id UniprotID NCBI GeneID
# 0             PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1        NCBIGene:1263580           external    83333       NaN     1263580
# 2             PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3               PR:P12499      organism gene    11683    P12499         NaN
# 4             PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                   ...                ...      ...       ...         ...
# 331975          PR:Q8AXL1      organism gene     9031    Q8AXL1         NaN
# 331976        PR:O09117-2  organism sequence    10090  O09117-2         NaN
# 331977       PR:000017637               gene      NaN       NaN         NaN
# 331978  Araport:AT1G74480           external     3702       NaN         NaN
# 331979       PR:000017654               gene      NaN       NaN         NaN
#
# [326674 rows x 8 columns]

# %% [markdown]
# # Merge Both Ontologies

# %%
df1 = pd.concat([pr_df,ogg_df])
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                                NaN
# 69684                                                NaN
# 69685                                                NaN
# 69686                                                NaN
# 69687                                                NaN
#
#                                                 Synonyms cross_reference  \
# 0                                        hSLCO3A1/iso:h3              []
# 1                                                    NaN             NaN
# 2                                            mILF2/iso:1              []
# 3      Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                       hCDC42BPA/iso:h6              []
# ...                                                  ...             ...
# 69683                                 mdl|JW5061|ECK0443             NaN
# 69684                                                NaN             NaN
# 69685                                     U62A|RNU62|U62             NaN
# 69686                                                NaN             NaN
# 69687               Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP             NaN
#
#                      id        type_of_ent taxon_id UniprotID NCBI GeneID  \
# 0           PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1      NCBIGene:1263580           external    83333       NaN     1263580
# 2           PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3             PR:P12499      organism gene    11683    P12499         NaN
# 4           PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                 ...                ...      ...       ...         ...
# 69683               NaN                NaN      NaN       NaN      945088
# 69684               NaN                NaN      NaN       NaN    13318740
# 69685               NaN                NaN      NaN       NaN       26786
# 69686               NaN                NaN      NaN       NaN   101928500
# 69687               NaN                NaN      NaN       NaN       22938
#
#       Preferred Label                           database_cross_reference  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 69683            mdlB                                    EcoGene:EG14374
# 69684       RVBD_0838                                                NaN
# 69685        SNORD62A                                         HGNC:10219
# 69686    LOC101928500                                                NaN
# 69687            SNW1  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#       full name from nomenclature authority organism NCBITaxon ID  \
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 69683                                   NaN                511145
# 69684                                   NaN                 83332
# 69685      small nucleolar RNA, C/D box 62A                  9606
# 69686                                   NaN                  9606
# 69687               SNW domain containing 1                  9606
#
#          type of gene
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 69683  protein-coding
# 69684  protein-coding
# 69685          snoRNA
# 69686           ncRNA
# 69687  protein-coding
#
# [396362 rows x 13 columns]

# %%
df1 = df1[(~df1.duplicated(subset='NCBI GeneID',keep='last')) | (df1['NCBI GeneID'].isnull())]

# %%
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                                NaN
# 69684                                                NaN
# 69685                                                NaN
# 69686                                                NaN
# 69687                                                NaN
#
#                                                 Synonyms cross_reference  \
# 0                                        hSLCO3A1/iso:h3              []
# 1                                                    NaN             NaN
# 2                                            mILF2/iso:1              []
# 3      Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34)|gag-pol (H...              []
# 4                                       hCDC42BPA/iso:h6              []
# ...                                                  ...             ...
# 69683                                 mdl|JW5061|ECK0443             NaN
# 69684                                                NaN             NaN
# 69685                                     U62A|RNU62|U62             NaN
# 69686                                                NaN             NaN
# 69687               Prp45|Bx42|SKIIP|PRPF45|NCOA-62|SKIP             NaN
#
#                      id        type_of_ent taxon_id UniprotID NCBI GeneID  \
# 0           PR:Q9UIG8-3  organism sequence     9606  Q9UIG8-3         NaN
# 1      NCBIGene:1263580           external    83333       NaN     1263580
# 2           PR:Q9CXY6-1  organism sequence    10090  Q9CXY6-1         NaN
# 3             PR:P12499      organism gene    11683    P12499         NaN
# 4           PR:Q5VT25-6  organism sequence     9606  Q5VT25-6         NaN
# ...                 ...                ...      ...       ...         ...
# 69683               NaN                NaN      NaN       NaN      945088
# 69684               NaN                NaN      NaN       NaN    13318740
# 69685               NaN                NaN      NaN       NaN       26786
# 69686               NaN                NaN      NaN       NaN   101928500
# 69687               NaN                NaN      NaN       NaN       22938
#
#       Preferred Label                           database_cross_reference  \
# 0                 NaN                                                NaN
# 1                 NaN                                                NaN
# 2                 NaN                                                NaN
# 3                 NaN                                                NaN
# 4                 NaN                                                NaN
# ...               ...                                                ...
# 69683            mdlB                                    EcoGene:EG14374
# 69684       RVBD_0838                                                NaN
# 69685        SNORD62A                                         HGNC:10219
# 69686    LOC101928500                                                NaN
# 69687            SNW1  HPRD:04340|MIM:603055|Ensembl:ENSG00000100603|...
#
#       full name from nomenclature authority organism NCBITaxon ID  \
# 0                                       NaN                   NaN
# 1                                       NaN                   NaN
# 2                                       NaN                   NaN
# 3                                       NaN                   NaN
# 4                                       NaN                   NaN
# ...                                     ...                   ...
# 69683                                   NaN                511145
# 69684                                   NaN                 83332
# 69685      small nucleolar RNA, C/D box 62A                  9606
# 69686                                   NaN                  9606
# 69687               SNW domain containing 1                  9606
#
#          type of gene
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 69683  protein-coding
# 69684  protein-coding
# 69685          snoRNA
# 69686           ncRNA
# 69687  protein-coding
#
# [396028 rows x 13 columns]

# %%
df1['Term'] = df1.apply(lambda x: set_term(x['Preferred Label'],x.Term),axis=1)
df1.drop('Preferred Label',axis=1,inplace=True)

# %%
df1['Synonyms'] = df1.apply(lambda x: set_term(x.Synonyms,x['full name from nomenclature authority']),axis=1)
df1.drop('full name from nomenclature authority',axis=1,inplace=True)

# %%
df1['cross_reference'] = df1['cross_reference'].apply(lambda x: np.nan if x == [] else x)

# %%
df1['NCBItaxon_id'] = df1.apply(lambda x: set_term(x['taxon_id'],x['organism NCBITaxon ID']),axis=1)
df1.drop(['organism NCBITaxon ID','taxon_id'],axis=1,inplace=True)

# %%
df1['cross_reference'] = df1['cross_reference'].apply(lambda d: d if isinstance(d, list) else [])

# %%
df1['database_cross_reference'] = df1['database_cross_reference'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [] )

# %%
df1['id'] = df1['id'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [] )

# %%
df1['cross_reference'] = df1['cross_reference'] + df1['database_cross_reference'] + df1['id']

# %%
df1.drop(['database_cross_reference','id'],axis=1,inplace=True)

# %%
df1.sample(10)
# Out:
#                                                     Term  \
# 100307                       centlein isoform m4 (mouse)
# 46186   inhibitor of growth protein 5 isoform h2 (human)
# 235358                 rpsI (Shewanella oneidensis MR-1)
# 189722                                 ptmaa (zebrafish)
# 13984                                            SNRPGP2
# 254312                                    SLC6A8 (human)
# 190079                   sperm-egg fusion protein TMEM95
# 75627                             flagellar protein FliO
# 250245                 DENN domain-containing protein 4B
# 170106                       dystonin isoform m5 (mouse)
#
#                                                  Synonyms  \
# 100307                                      mCNTLN/iso:m4
# 46186                                        hING5/iso:h2
# 235358                                                NaN
# 189722                                                NaN
# 13984                                             HsT2742
# 254312                                                NaN
# 190079   TMEM95|transmembrane protein 95|UNQ9390/PRO34281
# 75627                                      fliO|flaP|flbD
# 250245  DENND4B|brain specific protein 4|brain-specifi...
# 170106       dystonin isoform BPAG1-e (mouse)|mDST/iso:m5
#
#                     cross_reference        type_of_ent UniprotID NCBI GeneID  \
# 100307                [PR:A2AM05-4]  organism sequence  A2AM05-4         NaN
# 46186                 [PR:Q8WYH8-2]  organism sequence  Q8WYH8-2         NaN
# 235358           [NCBIGene:1171577]           external       NaN     1171577
# 189722  [ZFIN:ZDB-GENE-030131-7647]           external       NaN         NaN
# 13984                  [HGNC:30999]                NaN       NaN   100130003
# 254312                 [HGNC:11055]           external       NaN         NaN
# 190079               [PR:000032608]               gene       NaN         NaN
# 75627                [PR:000033309]               gene       NaN         NaN
# 250245               [PR:000031876]               gene       NaN         NaN
# 170106                [PR:Q91ZU6-5]  organism sequence  Q91ZU6-5         NaN
#
#        type of gene NCBItaxon_id
# 100307          NaN        10090
# 46186           NaN         9606
# 235358          NaN       211586
# 189722          NaN         7955
# 13984        pseudo         9606
# 254312          NaN         9606
# 190079          NaN          NaN
# 75627           NaN          NaN
# 250245          NaN          NaN
# 170106          NaN        10090

# %%
df1['type of gene'] = df1['type of gene'].apply(lambda d: d + ' gene' if isinstance(d, str) else np.nan)

# %%
df1['type'] = df1.apply(lambda x: set_term(x.type_of_ent,x['type of gene']),axis=1)
df1.drop(['type of gene','type_of_ent'],axis=1,inplace=True)

# %%
df1['Synonyms'] = df1['Synonyms'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else np.nan )

# %%
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 69683                                               mdlB
# 69684                                          RVBD_0838
# 69685                                           SNORD62A
# 69686                                       LOC101928500
# 69687                                               SNW1
#
#                                                 Synonyms  \
# 0                                      [hSLCO3A1/iso:h3]
# 1                                                    NaN
# 2                                          [mILF2/iso:1]
# 3      [Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34), gag-pol ...
# 4                                     [hCDC42BPA/iso:h6]
# ...                                                  ...
# 69683                             [mdl, JW5061, ECK0443]
# 69684                                                NaN
# 69685                                 [U62A, RNU62, U62]
# 69686                                                NaN
# 69687        [Prp45, Bx42, SKIIP, PRPF45, NCOA-62, SKIP]
#
#                                          cross_reference UniprotID  \
# 0                                          [PR:Q9UIG8-3]  Q9UIG8-3
# 1                                     [NCBIGene:1263580]       NaN
# 2                                          [PR:Q9CXY6-1]  Q9CXY6-1
# 3                                            [PR:P12499]    P12499
# 4                                          [PR:Q5VT25-6]  Q5VT25-6
# ...                                                  ...       ...
# 69683                                  [EcoGene:EG14374]       NaN
# 69684                                                 []       NaN
# 69685                                       [HGNC:10219]       NaN
# 69686                                                 []       NaN
# 69687  [HPRD:04340, MIM:603055, Ensembl:ENSG000001006...       NaN
#
#       NCBI GeneID NCBItaxon_id                 type
# 0             NaN         9606    organism sequence
# 1         1263580        83333             external
# 2             NaN        10090    organism sequence
# 3             NaN        11683        organism gene
# 4             NaN         9606    organism sequence
# ...           ...          ...                  ...
# 69683      945088       511145  protein-coding gene
# 69684    13318740        83332  protein-coding gene
# 69685       26786         9606          snoRNA gene
# 69686   101928500         9606           ncRNA gene
# 69687       22938         9606  protein-coding gene
#
# [396028 rows x 7 columns]

# %%
df1.count()
# Out:
# Term               396027
# Synonyms           265007
# cross_reference    396028
# UniprotID          170646
# NCBI GeneID         74587
# NCBItaxon_id       356713
# type               393915
# dtype: int64

# %% [markdown]
# ## Apend Gene Ontology terms

# %%
df1 = pd.concat([df1,go_df])

# %%
df1
# Out:
#                                                     Term  \
# 0      solute carrier organic anion transporter famil...
# 1                           trbG (Escherichia coli K-12)
# 2      interleukin enhancer-binding factor 2 isoform ...
# 3      gag-pol polyprotein (Human immunodeficiency vi...
# 4      serine/threonine-protein kinase MRCK alpha iso...
# ...                                                  ...
# 50597  negative regulation of ribosomal large subunit...
# 50600  2,5-dihydroxypyridine catabolic process to fum...
# 50601                               chylomicron assembly
# 50603                    pyrithiamine deaminase activity
# 50604                     sulfite dehydrogenase activity
#
#                                                 Synonyms  \
# 0                                      [hSLCO3A1/iso:h3]
# 1                                                    NaN
# 2                                          [mILF2/iso:1]
# 3      [Pr160Gag-Pol (HIV-1 M:D_Z2/CDC-Z34), gag-pol ...
# 4                                     [hCDC42BPA/iso:h6]
# ...                                                  ...
# 50597  [negative regulation of ribosomal large subuni...
# 50600  [2,5-dihydroxypyridine breakdown to fumarate, ...
# 50601                                                NaN
# 50603  [1-(4-amino-2-methylpyrimid-5-ylmethyl)-3-(bet...
# 50604  [sulphite dehydrogenase activity, sulfite:ferr...
#
#                                          cross_reference UniprotID  \
# 0                                          [PR:Q9UIG8-3]  Q9UIG8-3
# 1                                     [NCBIGene:1263580]       NaN
# 2                                          [PR:Q9CXY6-1]  Q9CXY6-1
# 3                                            [PR:P12499]    P12499
# 4                                          [PR:Q5VT25-6]  Q5VT25-6
# ...                                                  ...       ...
# 50597                                                NaN       NaN
# 50600                                  [MetaCyc:PWY-722]       NaN
# 50601                                                NaN       NaN
# 50603  [RHEA:14537, MetaCyc:PYRITHIAMIN-DEAMINASE-RXN...       NaN
# 50604  [MetaCyc:SULFITE-DEHYDROGENASE-RXN, EC:1.8.2.1...       NaN
#
#       NCBI GeneID NCBItaxon_id                type    GO_id
# 0             NaN         9606   organism sequence      NaN
# 1         1263580        83333            external      NaN
# 2             NaN        10090   organism sequence      NaN
# 3             NaN        11683       organism gene      NaN
# 4             NaN         9606   organism sequence      NaN
# ...           ...          ...                 ...      ...
# 50597         NaN          NaN  biological process  2000204
# 50600         NaN          NaN  biological process  0019508
# 50601         NaN          NaN  biological process  0034378
# 50603         NaN          NaN  molecular function  0050239
# 50604         NaN          NaN  molecular function  0050310
#
# [440015 rows x 8 columns]

# %% [markdown]
# # CTD Genes

# %%
ctd_df = pd.read_csv('data/Genetic/CTD_genes.csv', dtype=str)
ctd_df
# Out:
#                GeneSymbol                                           GeneName  \
# 0                  03B03F            DNA segment, 03B03F (Research Genetics)
# 1                  03B03R            DNA segment, 03B03R (Research Genetics)
# 2       03.MMHAP34FRA.SEQ                     DNA segment, 03.MMHAP34FRA.seq
# 3                   064YA                                                NaN
# 4                 102G4T7                               DNA segment, 102g4T7
# ...                   ...                                                ...
# 544904            ZZEF1.S  zinc finger, ZZ-type with EF-hand domain 1 S h...
# 544905              ZZZ-1     G_PROTEIN_RECEP_F1_2 domain-containing protein
# 544906               ZZZ3                   zinc finger ZZ-type containing 3
# 544907             ZZZ3.L       zinc finger, ZZ-type containing 3 L homeolog
# 544908             ZZZ3.S       zinc finger, ZZ-type containing 3 S homeolog
#
#            GeneID                                         AltGeneIDs  \
# 0           27777                                                NaN
# 1           27778                                                NaN
# 2           53288                                                NaN
# 3         5658107                                                NaN
# 4           56573                                                NaN
# ...           ...                                                ...
# 544904  108709661                                                NaN
# 544905     185208                                                NaN
# 544906      26009  100053222|100074855|100227013|100343576|100379...
# 544907  108714197                                                NaN
# 544908  108715504                                                NaN
#
#                                                  Synonyms     BioGRIDIDs  \
# 0                                                     NaN            NaN
# 1                                                     NaN            NaN
# 2                                                     NaN            NaN
# 3                                                     NaN            NaN
# 4                                                     NaN            NaN
# ...                                                   ...            ...
# 544904  XELAEV_18015398mg|zinc finger ZZ-type and EF-h...            NaN
# 544905                                      CELE_F32D8.10            NaN
# 544906  A306_07098|Anapl_04670|AS27_00889|ATAC1|ATAC c...  117482|224485
# 544907  XELAEV_18022920mg|ZZ-type zinc finger-containi...            NaN
# 544908  XELAEV_18025071mg|ZZ-type zinc finger-containi...            NaN
#
#         PharmGKBIDs                                         UniProtIDs
# 0               NaN                                                NaN
# 1               NaN                                                NaN
# 2               NaN                                                NaN
# 3               NaN                                                NaN
# 4               NaN                                                NaN
# ...             ...                                                ...
# 544904          NaN                                         A0A1L8H8K3
# 544905          NaN                                             Q19959
# 544906  PA134873184  A0A096MN54|A0A0D9S6Y1|A0A1A7ZGG4|A0A1D5QUG5|A0...
# 544907          NaN                                         A0A1L8GLP2
# 544908          NaN                                         A0A1L8GF94
#
# [544909 rows x 8 columns]

# %%
ctd_df.drop('AltGeneIDs',axis=1,inplace=True)

# %%
ctd_df['Synonyms'] = ctd_df['Synonyms'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['GeneName'] = ctd_df['GeneName'].apply(lambda x: [i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['Synonyms'] = ctd_df['Synonyms'] + ctd_df['GeneName']

# %%
ctd_df.drop('GeneName',axis=1,inplace=True)

# %%
ctd_df['BioGRIDIDs'] = ctd_df['BioGRIDIDs'].apply(lambda x: ['BioGRIDIDs:' + i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['PharmGKBIDs'] = ctd_df['PharmGKBIDs'].apply(lambda x: ['PharmGKBIDs:' + i for i in x.split('|')] if isinstance(x,str) else [])

# %%
ctd_df['cross_reference'] = ctd_df['BioGRIDIDs'] + ctd_df['PharmGKBIDs']
ctd_df.drop(['PharmGKBIDs','BioGRIDIDs'],axis=1,inplace=True)

# %%
ctd_df.rename(columns={'GeneID':'NCBI GeneID','UniProtIDs':'UniprotID','GeneSymbol':'Term'},inplace=True)

# %%
ctd_df.sample(10)
# Out:
#                    Term NCBI GeneID  \
# 519191        TSP_08207    10906771
# 68191         BM1_36045     6102096
# 89348       C5S72_MGT16    35987226
# 185698      E2990_MGT21    39412053
# 401298            PATZ1       23598
# 473982         T23B12.5      188777
# 77096        BVC38_GT20    30685962
# 527394        TSPAN31.S      495004
# 458394  SRAE_1000184200    36375947
# 519197        TSP_08213    10906777
#
#                                                  Synonyms  \
# 519191             [nuclease domain-containing protein 1]
# 68191          [bZIP transcription factor family protein]
# 89348                                              [tRNA]
# 185698                                             [tRNA]
# 401298  [A306_02535, and zinc finger-containing protei...
# 473982           [CELE_T23B12.5, Uncharacterized protein]
# 77096                                              [tRNA]
# 527394  [sarcoma-amplified sequence homolog A, sas, te...
# 458394   [Basic-leucine zipper domain-containing protein]
# 519197                     [absent in melanoma 1 protein]
#
#                                                 UniprotID  \
# 519191                                                NaN
# 68191                               A0A0K0JF08|A0A4E9FS26
# 89348                                                 NaN
# 185698                                                NaN
# 401298  A0A024R1F8|A0A024R1H7|A0A024R1M5|A0A087YJF3|A0...
# 473982                                             O17000
# 77096                                                 NaN
# 527394                                  A0A1L8H9X1|Q5XHG6
# 458394                                                NaN
# 519197                                                NaN
#
#                                           cross_reference
# 519191                                                 []
# 68191                                                  []
# 89348                                                  []
# 185698                                                 []
# 401298  [BioGRIDIDs:117133, BioGRIDIDs:207852, PharmGK...
# 473982                                                 []
# 77096                                                  []
# 527394                                                 []
# 458394                                                 []
# 519197                                                 []

# %% [markdown]
# # Merge all DataFrames

# %%
df_final = pd.concat([ctd_df,df1])
df_final
# Out:
#                                                     Term NCBI GeneID  \
# 0                                                 03B03F       27777
# 1                                                 03B03R       27778
# 2                                      03.MMHAP34FRA.SEQ       53288
# 3                                                  064YA     5658107
# 4                                                102G4T7       56573
# ...                                                  ...         ...
# 50597  negative regulation of ribosomal large subunit...         NaN
# 50600  2,5-dihydroxypyridine catabolic process to fum...         NaN
# 50601                               chylomicron assembly         NaN
# 50603                    pyrithiamine deaminase activity         NaN
# 50604                     sulfite dehydrogenase activity         NaN
#
#                                                 Synonyms UniprotID  \
# 0              [DNA segment, 03B03F (Research Genetics)]       NaN
# 1              [DNA segment, 03B03R (Research Genetics)]       NaN
# 2                       [DNA segment, 03.MMHAP34FRA.seq]       NaN
# 3                                                     []       NaN
# 4                                 [DNA segment, 102g4T7]       NaN
# ...                                                  ...       ...
# 50597  [negative regulation of ribosomal large subuni...       NaN
# 50600  [2,5-dihydroxypyridine breakdown to fumarate, ...       NaN
# 50601                                                NaN       NaN
# 50603  [1-(4-amino-2-methylpyrimid-5-ylmethyl)-3-(bet...       NaN
# 50604  [sulphite dehydrogenase activity, sulfite:ferr...       NaN
#
#                                          cross_reference NCBItaxon_id  \
# 0                                                     []          NaN
# 1                                                     []          NaN
# 2                                                     []          NaN
# 3                                                     []          NaN
# 4                                                     []          NaN
# ...                                                  ...          ...
# 50597                                                NaN          NaN
# 50600                                  [MetaCyc:PWY-722]          NaN
# 50601                                                NaN          NaN
# 50603  [RHEA:14537, MetaCyc:PYRITHIAMIN-DEAMINASE-RXN...          NaN
# 50604  [MetaCyc:SULFITE-DEHYDROGENASE-RXN, EC:1.8.2.1...          NaN
#
#                      type    GO_id
# 0                     NaN      NaN
# 1                     NaN      NaN
# 2                     NaN      NaN
# 3                     NaN      NaN
# 4                     NaN      NaN
# ...                   ...      ...
# 50597  biological process  2000204
# 50600  biological process  0019508
# 50601  biological process  0034378
# 50603  molecular function  0050239
# 50604  molecular function  0050310
#
# [984924 rows x 8 columns]

# %%
df_final = df_final[(~df_final.duplicated(subset='NCBI GeneID',keep='first')) | (df_final['NCBI GeneID'].isnull())]
print(df_final.shape)
# Out:
# (946584, 8)

# %%
df_final['UniprotID'] = df_final['UniprotID'].apply(lambda x: [f for f in x.split('|')] if isinstance(x,str) else np.nan)

# %%
df_final.count()
# Out:
# Term               946582
# NCBI GeneID        581156
# Synonyms           803547
# UniprotID          430954
# cross_reference    911592
# NCBItaxon_id       318373
# type               399562
# GO_id               43987
# dtype: int64

# %%
df_final.sample(10)
# Out:
#                                                      Term NCBI GeneID  \
# 423127                                               RDH8       50700
# 37440                              pronephros development         NaN
# 405448                                    PHUM_PHUM131500     8234162
# 234274                                        H2O20_MGT11    56138382
# 392727                                            OR12D26   100058631
# 239047                                  HELRODRAFT_113366    20195420
# 225075                                        Vps29 (rat)         NaN
# 262279              WD repeat-containing protein 35 (rat)         NaN
# 33009                                     Fpr-rs7 (mouse)         NaN
# 182564  submaxillary gland androgen-regulated protein ...         NaN
#
#                                                  Synonyms  \
# 423127  [AS28_00214, Cadr_000025383, CK820_G0026559, C...
# 37440                     [pronephric kidney development]
# 405448  [lipopolysaccharide-induced transcription fact...
# 234274                                             [tRNA]
# 392727  [olfactory receptor 12D3-like, olfactory recep...
# 239047                             [hypothetical protein]
# 225075                                                NaN
# 262279                      [rWDR35, naofen (rat), Wdr35]
# 33009                                                 NaN
# 182564                                  [mSmr2/iso:alpha]
#
#                                                 UniprotID  \
# 423127  [A0A091DE59, A0A1S2ZXC9, A0A1S3GN20, A0A1U7QT8...
# 37440                                                 NaN
# 405448                                           [E0VEE2]
# 234274                                                NaN
# 392727                                       [A0A3Q2HRK2]
# 239047                                           [T1EFR8]
# 225075                                                NaN
# 262279                                           [A6N6J5]
# 33009                                                 NaN
# 182564                                         [O09133-1]
#
#                                  cross_reference NCBItaxon_id  \
# 423127  [BioGRIDIDs:119119, PharmGKBIDs:PA34309]          NaN
# 37440                                        NaN          NaN
# 405448                                        []          NaN
# 234274                                        []          NaN
# 392727                                        []          NaN
# 239047                                        []          NaN
# 225075                             [RGD:1308332]        10116
# 262279                               [PR:A6N6J5]        10116
# 33009                              [MGI:2448177]        10090
# 182564                             [PR:O09133-1]        10090
#
#                       type    GO_id
# 423127                 NaN      NaN
# 37440   biological process  0048793
# 405448                 NaN      NaN
# 234274                 NaN      NaN
# 392727                 NaN      NaN
# 239047                 NaN      NaN
# 225075            external      NaN
# 262279       organism gene      NaN
# 33009             external      NaN
# 182564   organism sequence      NaN

# %% [markdown]
# # To JSON Genetic document

# %%
df_final.fillna('',inplace=True)

# %%
df_final.cross_reference = df_final.cross_reference.apply(lambda y: '' if len(y)==0 else y)

# %%
df_final.sample(5)
# Out:
#                                                    Term NCBI GeneID  \
# 226417                                      G7W86_MGT20    44151287
# 360124                                      MS3_0020292    24588721
# 382233                                     NECAME_18047    25358072
# 42596   diablo homolog, mitochondrial isoform 1 (human)
# 306439                                       LOAG_12746     9950212
#
#                                     Synonyms     UniprotID cross_reference  \
# 226417                                [tRNA]
# 360124  [MS3_00934, uncharacterized protein]  [A0A094ZG88]
# 382233                [hypothetical protein]      [W2TGD5]
# 42596                        [hDIABLO/iso:1]    [Q9NR28-1]   [PR:Q9NR28-1]
# 306439                [hypothetical protein]  [A0A1I7VC07]
#
#        NCBItaxon_id               type GO_id
# 226417
# 360124
# 382233
# 42596          9606  organism sequence
# 306439

# %%
documents = []
num = 0;
for i in df_final.itertuples(index=False):
    gene_document = {}
    gene_document['term'] = i[0]
    gene_document['synonyms']= i[2]
    gene_document['uniprot_id']= i[3]
    gene_document['ncbi_gene_id']= i[1]
    gene_document['ncbi_taxon_id'] = i[5]
    gene_document['type']= i[6]
    gene_document['cross_reference']= i[4]
    gene_document['GO_id']= i[7]  
    documents.append(gene_document) 
    num+=1
    if num%50000 == 0:
        print(num/len(df_final)*100,'% genes processed')
# Out:
# 5.2821513991362625 % genes processed
# 10.564302798272525 % genes processed
# 15.846454197408788 % genes processed
# 21.12860559654505 % genes processed
# 26.41075699568131 % genes processed
# 31.692908394817575 % genes processed
# 36.97505979395384 % genes processed
# 42.2572111930901 % genes processed
# 47.53936259222636 % genes processed
# 52.82151399136262 % genes processed
# 58.10366539049889 % genes processed
# 63.38581678963515 % genes processed
# 68.66796818877141 % genes processed
# 73.95011958790768 % genes processed
# 79.23227098704395 % genes processed
# 84.5144223861802 % genes processed
# 89.79657378531647 % genes processed
# 95.07872518445272 % genes processed

# %%
len(documents)
# Out:
# 946584

# %%
documents[654363]
# Out:
# {'term': 'putative ATP-dependent RNA helicase DHX57 isoform h3 (human)',
#  'synonyms': ['hDHX57/iso:h3'],
#  'uniprot_id': ['Q6P158-3'],
#  'ncbi_gene_id': '',
#  'ncbi_taxon_id': '9606',
#  'type': 'organism sequence',
#  'cross_reference': ['PR:Q6P158-3'],
#  'GO_id': ''}

# %% [markdown]
# ## Save and load resultant document

# %%
with open('data/Genetic/genetic.json', 'w') as fout:
    json.dump(documents, fout)

# %%
with open('data/Genetic/genetic.json', 'r') as fout:
    genetic = json.loads(fout.read())
    print(len(genetic))
# Out:
# 946584
