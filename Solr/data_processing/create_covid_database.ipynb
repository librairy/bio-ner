# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Drug Targets

# %%
drug_targets = pd.read_csv('data/COVID/drug_target.csv')
drug_targets
# Out:
#                                                Evidence  \
# 0     Evidence for GABRQ in COVID-19 (https://www.ta...
# 1     Evidence for TMPRSS2 in COVID-19 (https://www....
# 2     Evidence for RB1 in COVID-19 (https://www.targ...
# 3     Evidence for RPN1 in COVID-19 (https://www.tar...
# 4     Evidence for CHMP3 in COVID-19 (https://www.ta...
# ...                                                 ...
# 1356  Evidence for ORM2 in COVID-19 (https://www.tar...
# 1357  Evidence for MPZ in COVID-19 (https://www.targ...
# 1358  Evidence for LAMP3 in COVID-19 (https://www.ta...
# 1359  Evidence for PKM in COVID-19 (https://www.targ...
# 1360  Evidence for CCL21 in COVID-19 (https://www.ta...
#
#                                        Cross-references  \
# 0     Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 1     Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 2     Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 3     Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 4     Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# ...                                                 ...
# 1356  Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 1357  Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 1358  Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 1359  Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
# 1360  Ensembl Gene (1) (https://www.ebi.ac.uk/ebisea...
#
#                                                  Target  \
# 0     GABRQ (https://www.covid19dataportal.org//www....
# 1     TMPRSS2 (https://www.covid19dataportal.org//ww...
# 2     RB1 (https://www.covid19dataportal.org//www.ta...
# 3     RPN1 (https://www.covid19dataportal.org//www.t...
# 4     CHMP3 (https://www.covid19dataportal.org//www....
# ...                                                 ...
# 1356  ORM2 (https://www.covid19dataportal.org//www.t...
# 1357  MPZ (https://www.covid19dataportal.org//www.ta...
# 1358  LAMP3 (https://www.covid19dataportal.org//www....
# 1359  PKM (https://www.covid19dataportal.org//www.ta...
# 1360  CCL21 (https://www.covid19dataportal.org//www....
#
#       COVID-19 association score
# 0                          1.000
# 1                          1.000
# 2                          1.000
# 3                          1.000
# 4                          1.000
# ...                          ...
# 1356                       0.006
# 1357                       0.008
# 1358                       0.006
# 1359                       0.010
# 1360                       0.007
#
# [1361 rows x 4 columns]

# %%
drug_targets['evidence_url'] = drug_targets['Evidence'].apply(lambda x: x[x.find('https:'):-1])

# %%
drug_targets.iloc[0].evidence_url
# Out:
# 'https://www.targetvalidation.org/evidence/ENSG00000268089/MONDO_0100096'

# %%
drug_targets['Term'] = drug_targets['Target'].apply(lambda x: x[:x.find(' (')])

# %%
drug_targets['target_url'] = drug_targets['Target'].apply(lambda x: 'https://' + x[x.find('www.target'):-1])

# %%
drug_targets.iloc[0].target_url
# Out:
# 'https://www.targetvalidation.org/target/ENSG00000268089'

# %%
drug_targets['ebi_reference'] = drug_targets['Cross-references'].apply(lambda x: x[x.find('https://'):x.find(') On')])

# %%
drug_targets.iloc[432].ebi_reference
# Out:
# 'https://www.ebi.ac.uk/ebisearch/crossrefsearch.ebi?db=opentargets&id=ENSG00000095464-MONDO_0100096&ref=ensembl_gene'

# %%
drug_targets = drug_targets.drop(['Evidence','Cross-references','Target'],axis=1)

# %%
drug_targets
# Out:
#       COVID-19 association score  \
# 0                          1.000
# 1                          1.000
# 2                          1.000
# 3                          1.000
# 4                          1.000
# ...                          ...
# 1356                       0.006
# 1357                       0.008
# 1358                       0.006
# 1359                       0.010
# 1360                       0.007
#
#                                            evidence_url     Term  \
# 0     https://www.targetvalidation.org/evidence/ENSG...    GABRQ
# 1     https://www.targetvalidation.org/evidence/ENSG...  TMPRSS2
# 2     https://www.targetvalidation.org/evidence/ENSG...      RB1
# 3     https://www.targetvalidation.org/evidence/ENSG...     RPN1
# 4     https://www.targetvalidation.org/evidence/ENSG...    CHMP3
# ...                                                 ...      ...
# 1356  https://www.targetvalidation.org/evidence/ENSG...     ORM2
# 1357  https://www.targetvalidation.org/evidence/ENSG...      MPZ
# 1358  https://www.targetvalidation.org/evidence/ENSG...    LAMP3
# 1359  https://www.targetvalidation.org/evidence/ENSG...      PKM
# 1360  https://www.targetvalidation.org/evidence/ENSG...    CCL21
#
#                                              target_url  \
# 0     https://www.targetvalidation.org/target/ENSG00...
# 1     https://www.targetvalidation.org/target/ENSG00...
# 2     https://www.targetvalidation.org/target/ENSG00...
# 3     https://www.targetvalidation.org/target/ENSG00...
# 4     https://www.targetvalidation.org/target/ENSG00...
# ...                                                 ...
# 1356  https://www.targetvalidation.org/target/ENSG00...
# 1357  https://www.targetvalidation.org/target/ENSG00...
# 1358  https://www.targetvalidation.org/target/ENSG00...
# 1359  https://www.targetvalidation.org/target/ENSG00...
# 1360  https://www.targetvalidation.org/target/ENSG00...
#
#                                           ebi_reference
# 0     https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 1     https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 2     https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 3     https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 4     https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# ...                                                 ...
# 1356  https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 1357  https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 1358  https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 1359  https://www.ebi.ac.uk/ebisearch/crossrefsearch...
# 1360  https://www.ebi.ac.uk/ebisearch/crossrefsearch...
#
# [1361 rows x 5 columns]

# %% [markdown]
# # COVID Proteins

# %%
prot = pd.read_csv('data/COVID/proteins_covid.tsv', delimiter='\t')
prot.head()
# Out:
#           PRO ID                                           PRO Name   \
# 0   PR:000050262   severe acute respiratory syndrome coronavirus ...
# 1  PR:A0A663DJA2                        ORF10 protein (SARS-CoV-2)
# 2   PR:000050387           N gene translation product (SARS-CoV-2)
# 3      PR:P0DTD8                        ORF7b protein (SARS-CoV-2)
# 4      PR:P0DTC8                         ORF8 protein (SARS-CoV-2)
#
#                                 PRO Term Definition         Category   \
# 0  A protein that is encoded in the genome of Sev...
# 1  A protein that is a translation product of the...  organism-gene
# 2  A protein that is a translation product of the...  organism-gene
# 3  A protein that is a translation product of the...  organism-gene
# 4  A protein that is a translation product of the...  organism-gene
#
#           Parent
# 0  PR:000036197
# 1  PR:000050262
# 2  PR:000050262
# 3  PR:000050262
# 4  PR:000050262

# %%
prot['Term'] = prot['PRO Name '].apply(lambda x: x[:x.find('(SARS')])

# %%
prot.columns
# Out:
# Index(['PRO ID ', 'PRO Name ', 'PRO Term Definition ', 'Category ', 'Parent ',
#        'Term'],
#       dtype='object')

# %%
prot['PR_id'] = prot['PRO ID ']

# %%
prot = prot.drop(['PRO ID ','PRO Name ','PRO Term Definition ','Category ','Parent '],axis=1)

# %%
prot
# Out:
#                                                  Term           PR_id
# 0   severe acute respiratory syndrome coronavirus ...   PR:000050262
# 1                                      ORF10 protein   PR:A0A663DJA2
# 2                         N gene translation product    PR:000050387
# 3                                      ORF7b protein       PR:P0DTD8
# 4                                       ORF8 protein       PR:P0DTC8
# 5                                      ORF7a protein       PR:P0DTC7
# 6                                       ORF6 protein       PR:P0DTC6
# 7                                   membrane protein       PR:P0DTC5
# 8                    envelope small membrane protein       PR:P0DTC4
# 9                                      ORF3a protein       PR:P0DTC3
# 10                                spike glycoprotein       PR:P0DTC2
# 11                      rep gene translation product    PR:000050263
# 12                        uncharacterized protein 14     PR:P0DTD3-1
# 13                ORF1a proteolytic cleavage product    PR:000050282
# 14                                 spike protein S2'    PR:000050269
# 15                                     ORF9b protein       PR:P0DTD2
# 16                         replicase polyprotein 1ab     PR:P0DTD1-1
# 17                                     nucleoprotein     PR:P0DTC9-1
# 18                          replicase polyprotein 1a     PR:P0DTC1-1
# 19                               NSP2-3 intermediate    PR:000050289
# 20                                          helicase    PR:000050285
# 21               ORF1ab proteolytic cleavage product    PR:000050283
# 22             rep gene proteolytic cleavage product    PR:000050281
# 23                         non-structural protein 11    PR:000050280
# 24                                  spike protein S2    PR:000050268
# 25                                  spike protein S1    PR:000050267
# 26   spike glycoprotein, signal peptide removed form    PR:000050266
# 27        ORF7a protein, signal peptide removed form    PR:000050265
# 28         ORF8 protein, signal peptide removed form    PR:000050264
# 29                            2'-O-methyltransferase    PR:000050288
# 30               uridylate-specific endoribonuclease    PR:000050287
# 31                      proofreading exoribonuclease    PR:000050286
# 32                       RNA-directed RNA polymerase    PR:000050284
# 33                         non-structural protein 10    PR:000050279
# 34                          non-structural protein 9    PR:000050278
# 35                          non-structural protein 8    PR:000050277
# 36                          non-structural protein 7    PR:000050276
# 37                          non-structural protein 6    PR:000050275
# 38                                3C-like proteinase    PR:000050274
# 39                          non-structural protein 4    PR:000050273
# 40                          non-structural protein 2    PR:000050271
# 41                   host translation inhibitor nsp1    PR:000050270
# 42                          non-structural protein 3    PR:000050272

# %% [markdown]
# # Concatenate data

# %%
df = pd.concat([drug_targets,prot])
df
# Out:
#     COVID-19 association score  \
# 0                          1.0
# 1                          1.0
# 2                          1.0
# 3                          1.0
# 4                          1.0
# ..                         ...
# 38                         NaN
# 39                         NaN
# 40                         NaN
# 41                         NaN
# 42                         NaN
#
#                                          evidence_url  \
# 0   https://www.targetvalidation.org/evidence/ENSG...
# 1   https://www.targetvalidation.org/evidence/ENSG...
# 2   https://www.targetvalidation.org/evidence/ENSG...
# 3   https://www.targetvalidation.org/evidence/ENSG...
# 4   https://www.targetvalidation.org/evidence/ENSG...
# ..                                                ...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                 Term  \
# 0                              GABRQ
# 1                            TMPRSS2
# 2                                RB1
# 3                               RPN1
# 4                              CHMP3
# ..                               ...
# 38               3C-like proteinase
# 39         non-structural protein 4
# 40         non-structural protein 2
# 41  host translation inhibitor nsp1
# 42         non-structural protein 3
#
#                                            target_url  \
# 0   https://www.targetvalidation.org/target/ENSG00...
# 1   https://www.targetvalidation.org/target/ENSG00...
# 2   https://www.targetvalidation.org/target/ENSG00...
# 3   https://www.targetvalidation.org/target/ENSG00...
# 4   https://www.targetvalidation.org/target/ENSG00...
# ..                                                ...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                         ebi_reference          PR_id
# 0   https://www.ebi.ac.uk/ebisearch/crossrefsearch...            NaN
# 1   https://www.ebi.ac.uk/ebisearch/crossrefsearch...            NaN
# 2   https://www.ebi.ac.uk/ebisearch/crossrefsearch...            NaN
# 3   https://www.ebi.ac.uk/ebisearch/crossrefsearch...            NaN
# 4   https://www.ebi.ac.uk/ebisearch/crossrefsearch...            NaN
# ..                                                ...            ...
# 38                                                NaN  PR:000050274
# 39                                                NaN  PR:000050273
# 40                                                NaN  PR:000050271
# 41                                                NaN  PR:000050270
# 42                                                NaN  PR:000050272
#
# [1404 rows x 6 columns]

# %%
df = df.replace(np.nan,'')

# %% [markdown]
# # To JSON document

# %%
documents = []
for i in df.itertuples(index=False):
    doc = {}
    doc['term'] = i[2]
    doc['association_score']= i[0]
    doc['evidence_url']= i[1]
    doc['target_url']= i[3]
    doc['ebi_reference']= i[4]
    doc['PR_id']= i[5]
    documents.append(doc)

# %%
import json

# %%
with open('data/COVID/covid.json', 'w') as fout:
    json.dump(documents, fout)

# %%
with open('data/COVID/covid.json', 'r') as fout:
    covid = json.loads(fout.read())
    print(len(covid))
# Out:
# 1404
